# %%
import pandas as pd

# %% [markdown]
# # Create a Dataframe from a Dictionary

# %%
data = {
    'Date': ['05/06/2024', '05/06/2024', '05/06/2024', '05/06/2024', '06/08/2024'],
    'Route_Direction': ['In-Run', 'In-Run', 'Outrun', 'Outrun', 'In-Run'],
    'Mode_of_Transport': ['Trotro', 'Trotro', 'Trotro', 'Trotro', 'Trotro'],
    'Segment': ['Full Route', 'Shangrila to Airport 2nd', 'Full Route', 'Airport 2nd to Shangrila', 'Full Route'],
    'Start_Time': ['07:29 AM', '07:41 AM', '04:46 PM', '04:49 PM', '07:56 AM'],
    'Stop_Time': ['08:19 AM', '07:50 AM', '05:03 PM', '04:53 PM', '08:50 AM'],
    'Duration': ['49:25.73', '05:31', '17:56.45', '03:41.51', '54:19.52']
}

# Convert to DataFrame
df = pd.DataFrame(data)

# Display the DataFrame
df
# Out:
#          Date Route_Direction Mode_of_Transport                   Segment  \
# 0  05/06/2024          In-Run            Trotro                Full Route
# 1  05/06/2024          In-Run            Trotro  Shangrila to Airport 2nd
# 2  05/06/2024          Outrun            Trotro                Full Route
# 3  05/06/2024          Outrun            Trotro  Airport 2nd to Shangrila
# 4  06/08/2024          In-Run            Trotro                Full Route
#
#   Start_Time Stop_Time  Duration
# 0   07:29 AM  08:19 AM  49:25.73
# 1   07:41 AM  07:50 AM     05:31
# 2   04:46 PM  05:03 PM  17:56.45
# 3   04:49 PM  04:53 PM  03:41.51
# 4   07:56 AM  08:50 AM  54:19.52

# %% [markdown]
# # Creating Dataframe from a List of Dictionary

# %%
data = [
    {'Date':'05/06/2024','Route_Direction':'In-Run' ,'Mode_of_Transport':'Trotro' ,'Segment':
     'Full Route' ,'Start_Time':'07:29 AM' ,'Stop_Time': '08:19 AM' ,'Duration': '49:25.73' },
    
    {'Date':'05/06/2024','Route_Direction':'In-Run' ,'Mode_of_Transport':'Trotro' ,'Segment':
     'Shangrila to Airport 2nd' ,'Start_Time': '07:41 AM' ,'Stop_Time':'07:50 AM'  ,'Duration': '05:31' },
    
    {'Date': '05/06/2024','Route_Direction':'Outrun' ,'Mode_of_Transport':'Trotro' ,'Segment':
     'Full Route' ,'Start_Time': '04:46 PM' ,'Stop_Time': '05:03 PM' ,'Duration': '17:56.45'},
    
    {'Date': '05/06/2024','Route_Direction': 'Outrun' ,'Mode_of_Transport':'Trotro' ,'Segment':
     'Airport 2nd to Shangrila' ,'Start_Time': '04:49 PM' ,'Stop_Time':'04:53 PM' ,'Duration':'03:41.51'  },
    
    {'Date': '06/08/2024','Route_Direction':'In-Run' ,'Mode_of_Transport':'Trotro' ,'Segment':
     'Full Route' ,'Start_Time': '07:56 AM' ,'Stop_Time':'08:50 AM'  ,'Duration': '54:19.52'},
]

# Convert to DataFrame
df = pd.DataFrame(data)


# Display the DataFrame
df
# Out:
#          Date Route_Direction Mode_of_Transport                   Segment  \
# 0  05/06/2024          In-Run            Trotro                Full Route
# 1  05/06/2024          In-Run            Trotro  Shangrila to Airport 2nd
# 2  05/06/2024          Outrun            Trotro                Full Route
# 3  05/06/2024          Outrun            Trotro  Airport 2nd to Shangrila
# 4  06/08/2024          In-Run            Trotro                Full Route
#
#   Start_Time Stop_Time  Duration
# 0   07:29 AM  08:19 AM  49:25.73
# 1   07:41 AM  07:50 AM     05:31
# 2   04:46 PM  05:03 PM  17:56.45
# 3   04:49 PM  04:53 PM  03:41.51
# 4   07:56 AM  08:50 AM  54:19.52

# %% [markdown]
# # Creating a Series from a list of Lists

# %%
data = [
    ['05/06/2024','In-Run' ,'Trotro' ,'Full Route' ,'07:29 AM' ,'08:19 AM' , '49:25.73'],
    ['05/06/2024','In-Run' ,'Trotro' ,'Shangrila to Airport 2nd' , '07:41 AM' ,'07:50 AM'  , '05:31'],
]

# Convert to DataFrame
df = pd.DataFrame(data, columns=['Date','Route_Direction','Mode_of_Transport','Segment','Start_Time','Stop_Time','Duration'])

# Display the DataFrame
df
# Out:
#          Date Route_Direction Mode_of_Transport                   Segment  \
# 0  05/06/2024          In-Run            Trotro                Full Route
# 1  05/06/2024          In-Run            Trotro  Shangrila to Airport 2nd
#
#   Start_Time Stop_Time  Duration
# 0   07:29 AM  08:19 AM  49:25.73
# 1   07:41 AM  07:50 AM     05:31

# %% [markdown]
# # Creating Dataframe from multiple Series

# %%
date = pd.Series(['05/06/2024', '05/06/2024', '05/06/2024', '05/06/2024', '06/08/2024']) 
route = pd.Series(['In-Run', 'In-Run', 'Outrun', 'Outrun', 'In-Run'])
mode_of_transport = pd.Series(['Trotro', 'Trotro', 'Trotro', 'Trotro', 'Trotro'])
segment = pd.Series(['Full Route', 'Shangrila to Airport 2nd', 'Full Route', 'Airport 2nd to Shangrila', 'Full Route'])
start_time = pd.Series(['07:29 AM', '07:41 AM', '04:46 PM', '04:49 PM', '07:56 AM'])
stop_time = pd.Series(['08:19 AM', '07:50 AM', '05:03 PM', '04:53 PM', '08:50 AM'])
duration = pd.Series( ['49:25.73', '05:31', '17:56.45', '03:41.51', '54:19.52'])

df = pd.concat({'Date':date, 'Route_Direction':route,"Mode_of_Transport":mode_of_transport,
                "Segment":segment, "Start_Time":start_time,"Stop_Time":stop_time,"Duration":duration }, axis=1)


df
# Out:
#          Date Route_Direction Mode_of_Transport                   Segment  \
# 0  05/06/2024          In-Run            Trotro                Full Route
# 1  05/06/2024          In-Run            Trotro  Shangrila to Airport 2nd
# 2  05/06/2024          Outrun            Trotro                Full Route
# 3  05/06/2024          Outrun            Trotro  Airport 2nd to Shangrila
# 4  06/08/2024          In-Run            Trotro                Full Route
#
#   Start_Time Stop_Time  Duration
# 0   07:29 AM  08:19 AM  49:25.73
# 1   07:41 AM  07:50 AM     05:31
# 2   04:46 PM  05:03 PM  17:56.45
# 3   04:49 PM  04:53 PM  03:41.51
# 4   07:56 AM  08:50 AM  54:19.52

# %% [markdown]
# # Creating Dataframe from a csv file

# %%
df = pd.read_csv('data.csv')
df
# Out:
#           Date Route_Direction Mode_of_Transport                   Segment  \
# 0   05/06/2024          In-Run            Trotro                Full Route
# 1   05/06/2024          In-Run            Trotro  Shangrila to Airport 2nd
# 2   05/06/2024          Outrun            Trotro                Full Route
# 3   05/06/2024          Outrun            Trotro  Airport 2nd to Shangrila
# 4   06/08/2024          In-Run            Trotro                Full Route
# 5   06/08/2024          In-Run            Trotro  Shangrila to Airport 2nd
# 6   07/08/2024          In-Run            Trotro                Full Route
# 7   07/08/2024          In-Run            Trotro  Shangrila to Airport 2nd
# 8   07/08/2024          Outrun         Motorbike                Full Route
# 9   07/08/2024          Outrun         Motorbike  Airport 2nd to Shangrila
# 10  08/08/2024          In-Run            Trotro                Full Route
# ...

# %% [markdown]
# # Viewing Data

# %%
# View the first 5 rows
df.head()

# View the last 5 rows
# df.tail()

# Specify the number of rows to display
# df.head(10)
# df.tail(8)
# Out:
#          Date Route_Direction Mode_of_Transport                   Segment  \
# 0  05/06/2024          In-Run            Trotro                Full Route
# 1  05/06/2024          In-Run            Trotro  Shangrila to Airport 2nd
# 2  05/06/2024          Outrun            Trotro                Full Route
# 3  05/06/2024          Outrun            Trotro  Airport 2nd to Shangrila
# 4  06/08/2024          In-Run            Trotro                Full Route
#
#   Start_Time Stop_Time  Duration
# 0   07:29 AM  08:19 AM  49:25.73
# 1   07:41 AM  07:50 AM     05:31
# 2   04:46 PM  05:03 PM  17:56.45
# 3   04:49 PM  04:53 PM  03:41.51
# 4   07:56 AM  08:50 AM  54:19.52

# %% [markdown]
# # Retrieving DataFrame Labels and Data Types

# %%
# Get row labels
df.index

# Get column labels
# df.columns

# Get both row and column labels
# df.axes

# Check data types of each column
# df.dtypes

# Summary of the DataFrame
# df.info()
# Out:
# RangeIndex(start=0, stop=50, step=1)

# %% [markdown]
# # Modifying Column Data Types

# %%
# Convert using astype method
# Convert to category type
df = df.astype({
    'Route_Direction': 'category',
    'Mode_of_Transport': 'category',
    'Segment': 'category'
})

# Convert Date to datetime
df['Date'] = pd.to_datetime(df['Date'], format='%d/%m/%Y')

# Convert Start_Time and Stop_Time to datetime
df['Start_Time'] = pd.to_datetime(df['Start_Time'], format='%I:%M %p')
df['Stop_Time'] = pd.to_datetime(df['Stop_Time'], format='%I:%M %p')

# Preprocess the Duration column to add missing hour part (for entries in mm:ss format)
# If the duration is in mm:ss or mm:ss.microseconds format, add '00:' to make it hh:mm:ss.microseconds
# df['Duration'] = df['Duration'].apply(lambda x: '00:' + x if len(x.split(':')) == 2 else x)

# Convert Duration to timedelta
df['Duration'] = pd.to_timedelta(df['Duration'])

# To check data info
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               50 non-null     datetime64[ns]
#  1   Route_Direction    50 non-null     category
#  2   Mode_of_Transport  50 non-null     category
#  3   Segment            50 non-null     category
#  4   Start_Time         49 non-null     datetime64[ns]
#  5   Stop_Time          49 non-null     datetime64[ns]
#  6   Duration           50 non-null     timedelta64[ns]
# dtypes: category(3), datetime64[ns](3), timedelta64[ns](1)
# memory usage: 2.4 KB
# None

# %% [markdown]
# # Shape and Size of DataFrame

# %%
# Number of dimensions
# df.ndim

# Number of rows and columns
# df.shape

# Total number of elements
df.size
# Out:
# 350
