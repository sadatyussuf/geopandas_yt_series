# %%
import pandas as pd 
import  numpy as np

# %%
rows, cols = 5,3

data = np.random.randn(rows,cols)


df= pd.DataFrame(data,columns=[f'col_{i}' for i in range(cols)],index=[1, 2, 3, 5, 8])

df

# colors = pd.Series(
#     ["red", "purple", "blue", "green", "yellow"],
#    index=[1, 2, 3, 5, 8]
# )
# colors
# Out:
#       col_0     col_1     col_2
# 1  0.467965  0.823086 -1.583423
# 2 -0.236728  0.930543 -0.393730
# 3  0.613946  0.839053  1.655876
# 5 -1.054890 -0.586198  1.155198
# 8  0.659610  2.465685 -0.261807

# %%
df.col_0
# Out:
# 1    0.467965
# 2   -0.236728
# 3    0.613946
# 5   -1.054890
# 8    0.659610
# Name: col_0, dtype: float64

# %%
df[['col_0','col_2']]
# Out:
#       col_0     col_2
# 1  0.467965 -1.583423
# 2 -0.236728 -0.393730
# 3  0.613946  1.655876
# 5 -1.054890  1.155198
# 8  0.659610 -0.261807

# %%
df[:1]
# Out:
#       col_0     col_1     col_2
# 1  0.467965  0.823086 -1.583423

# %%
df[0:3]
# Out:
#       col_0     col_1     col_2
# 1  0.467965  0.823086 -1.583423
# 2 -0.236728  0.930543 -0.393730
# 3  0.613946  0.839053  1.655876

# %%
df
# Out:
#       col_0     col_1     col_2
# 1  0.467965  0.823086 -1.583423
# 2 -0.236728  0.930543 -0.393730
# 3  0.613946  0.839053  1.655876
# 5 -1.054890 -0.586198  1.155198
# 8  0.659610  2.465685 -0.261807

# %%
df.loc[3:]
# Out:
#       col_0     col_1     col_2
# 3  0.613946  0.839053  1.655876
# 5 -1.054890 -0.586198  1.155198
# 8  0.659610  2.465685 -0.261807

# %%
df.loc[3]
# Out:
# col_0    0.613946
# col_1    0.839053
# col_2    1.655876
# Name: 3, dtype: float64

# %%
df.loc['col_0']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\OSGeo4W\apps\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:175, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\index_class_helper.pxi:70, in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'col_0'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 df.loc['col_0']
#
# File C:\OSGeo4W\apps\Python312\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
# ...
