# %%
import geopandas as gpd
import pandas as pd

# %%
gdf = gpd.read_file("world_admin.gpkg")

# %%
gd
# Out:
#      iso3        status color_code                     name continent  \
# 0    None  PT Territory        PRT          Madeira Islands    Europe
# 1    None   Adm. by EGY        EGY          Ma'tan al-Sarra    Africa
# 2    None  US Territory        USA               Midway Is.  Americas
# 3     SAU  Member State        SAU             Saudi Arabia      Asia
# 4     MAR  Member State        MAR                  Morocco    Africa
# ..    ...           ...        ...                      ...       ...
# 251   ARG  Member State        ARG                Argentina  Americas
# 252   CCK  AU Territory        AUS  Cocos (Keeling) Islands      Asia
# 253   MUS  Member State        MUS                Mauritius    Africa
# 254   CHN  Member State        CHN                    China      Asia
# 255   JPN  Member State        JPN                    Japan      Asia
#
#                  region iso_3166_1_              french_shor  \
# 0       Southern Europe        None          Madeira Islands
# ...
