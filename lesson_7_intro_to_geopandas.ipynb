# %%
import geopandas as gpd
import pandas as pd

# %%
gdf = gpd.read_file("world_admin.gpkg")

# %%
gdf.head()
# Out:
#    iso3        status color_code             name continent            region  \
# 0  None  PT Territory        PRT  Madeira Islands    Europe   Southern Europe
# 1  None   Adm. by EGY        EGY  Ma'tan al-Sarra    Africa   Northern Africa
# 2  None  US Territory        USA       Midway Is.  Americas  Northern America
# 3   SAU  Member State        SAU     Saudi Arabia      Asia      Western Asia
# 4   MAR  Member State        MAR          Morocco    Africa   Northern Africa
#
#   iso_3166_1_      french_shor  \
# 0        None  Madeira Islands
# 1        None  Ma'tan al-Sarra
# 2        None       Midway Is.
# 3          SA  Arabie saoudite
# 4          MA            Maroc
#
#                                             geometry
# 0  MULTIPOLYGON (((-17.1025 32.82333, -17.05306 3...
# 1  MULTIPOLYGON (((33.25104 21.99977, 34.15064 21...
# 2  MULTIPOLYGON (((-177.38806 28.18638, -177.3933...
# 3  MULTIPOLYGON (((41.945 16.71083, 41.95777 16.7...
# ...

# %%
gdf.plot()
# Out:
# <Axes: >
